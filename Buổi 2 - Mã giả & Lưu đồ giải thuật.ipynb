# %% [markdown]
# # Mã giả & Lưu đồ giải thuật
#
# ### Lập trình
#
# Lập trình là gì?

# %% [markdown]
# Lập trình là đưa ra những câu lệnh để máy tính thực hiện.
#
# Đưa ra câu lệnh A, trước câu lệnh B thì câu lệnh A sẽ được thực hiện trước.

# %% [markdown]
# ### Thuật toán
#
# Thuật toán là gì?

# %% [markdown]
# Thuật toán là những câu lệnh được đưa ra để giải quyết một vấn đề nào đó.

# %% [markdown]
# ### Mã gỉả
#
# #### Khái niệm:
#
# Mã giả được viết với ngôn ngữ tự nhiên một thuật toán nào đó dùng để giải quyết một vấn đề lập trình.
#
# Mã giả được quy ước chung theo từng nơi làm việc.
#
# Ví dụ:
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (Món ăn)
# Nếu (món ăn còn):
#     Đặt (Món ăn)
# Ngược lại:
#     Nếu (Cơm sườn còn):
#         Đặt (Cơm sườn)
#     Ngược lại:
#         Đi ngủ

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a > 10):
#     In (Đúng)
# Ngược lại:
#     In (Sai)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a > 0):
#     In (a la số dương)
# Ngược lại:
#     Nếu (a < 0):
#         In (a là số âm)
#     Ngược lại:
#         In (a là số 0)

# %% [markdown]
# Lưu đồ giải thuật
#
# Lưu đồ giải thuật là một thuật toán được biểu diễn với dạng lưu đồ
#
# Công cụ vẽ lưu đồ giải thuật: https://draw.io/
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-12%20at%2023.06.44.png](attachment:Screen%20Shot%202022-09-12%20at%2023.06.44.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-12%20at%2022.58.55.png](attachment:Screen%20Shot%202022-09-12%20at%2022.58.55.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-12%20at%2023.03.08.png](attachment:Screen%20Shot%202022-09-12%20at%2023.03.08.png)

# %% [markdown]
# ### Bài tập
#
# <b>Đề bài</b>
#
# Nhập vào nhiệt độ C, chuyển sang độ F rồi in ra màn hình
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (C)
#     F = C * 33.8
#     In (F)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2010.16.30.png](attachment:Screen%20Shot%202022-09-13%20at%2010.16.30.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương tháng này, nếu lương tháng này nhiều hơn 2 triệu thì trừ đi 10% thuế, nếu không thì không trừ.
#
# Hãy tính và in ra lương thực nhận được
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (Lương)
# Nếu (Lương > 2000000):
#     Lương = Lương * 0.9
# In (Lương)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2010.35.07.png](attachment:Screen%20Shot%202022-09-13%20at%2010.35.07.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương thực nhận được tháng này, nếu lương ít hơn 10 triệu, đưa hết cho vợ, nếu lương nhiều hơn 10 triệu, vợ cho 10% lương
#
# Hãy tính và in ra màn hình phần lương mình được nhận
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (lương)
# Nếu (lương > 10000000):
#     lương = lương * 0.1
#     In (luong)
# Ngược lại:
#     In (0)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2010.40.10.png](attachment:Screen%20Shot%202022-09-13%20at%2010.40.10.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào số điểm văn và điểm toán, tính và in ra điểm trung bình, nếu điểm trung bình lớn hơn 8 thì in ra dòng chữ Học sinh giỏi, ngược lại thì in ra dòng chữ Không phải học sinh giỏi
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (dv, dt)
# ave = (dv + dt) * 0.5
# In (TB)
# Nếu (TB > 8):
#     In (Học sinh giỏi)
# Ngược lại:
#     In (Không phải học sinh giỏi)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2010.49.41.png](attachment:Screen%20Shot%202022-09-13%20at%2010.49.41.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra xem số đó có chia hết cho 5 hay không
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a % 5 == 0):
#     In (a chia hết cho 5)
# Ngược lại:
#     In (a không chia hết cho 5)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2010.53.09.png](attachment:Screen%20Shot%202022-09-13%20at%2010.53.09.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào điểm số, nếu điểm số lớn hơn hoặc bằng 8, in ra dòng chữ Học sinh giỏi, nếu điểm số bé hơn 8 và lớn hơn hoặc bằng 6, in ra dòng chữ chữ học sinh Khá, ngược lại in ra dòng chữ Học sinh trung bình
#
# <b>Mã giả:</b>

# %% [raw]
# Nhập (a)
# Nếu (a >= 8):
#     In (Học sinh giỏi)
# Ngược lại:
#     Nếu (a >= 6):
#         In (Học sinh khá)
#     Ngược lại:
#         In (Học sinh trung bình)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2011.01.41.png](attachment:Screen%20Shot%202022-09-13%20at%2011.01.41.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra tính chẳn lẻ và số đó có lớn hơn 10 hay không. (in ra 4 trường hợp: chẳn lớn hơn 10, lẻ lớn hơn 10, chẳn bé hơn hoặc bằng 10, lẻ bé hơn 10)
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập (a)
# Nếu (a % 2 == 0):
#     Nếu (a > 10):
#         In (Số chẵn lớn hơn 10)
#     Ngược lại:
#         In (Số chẵn bé hơn hoặc bằng 10)
# Ngược lại:
#     Nếu (a < 10)
#         In (Số lẻ lớn hơn 10)
#     Ngược lại:
#         In (Số lẻ bé hơn 10)

# %% [markdown]
# #2:
# Nhập (a)
# Nếu (a % 2 == 0 và a > 10):
#     In (Số chẵn lớn hơn 10)
# Ngược lại:
#     Nếu (a % 2 == 0 và a < = 10)
#         In (Số chẵn bé hơn hoặc bằng 10)
#     Ngược lại:
#         Nếu (a > 10):
#             In (Số lẻ lớn hơn 10)
#         Ngược lại:
#             In (Số lẻ bé hơn 10)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2011.15.26.png](attachment:Screen%20Shot%202022-09-13%20at%2011.15.26.png)

# %% [markdown]
# ![Screen%20Shot%202022-09-13%20at%2015.05.20.png](attachment:Screen%20Shot%202022-09-13%20at%2015.05.20.png)

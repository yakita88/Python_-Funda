# %%
def rectangular1(a):
    for i in range(2):
        t.fd(2.5*a)
        t.lt(90)
        t.fd(a)
        t.lt(90)
def rectangular2(a):
    for i in range(2):
        t.fd(a)
        t.lt(90)
        t.fd(4/3*a)
        t.lt(90)
def rectangular3(a):
    for i in range(2):
        t.fd(a)
        t.lt(90)
        t.fd(2.5*a)
        t.lt(90)

def triangle(a):
    t.lt(135)
    t.fd(a)
    t.lt(90)
    t.fd(a)

def triangle2(a):
    t.fd(a+20)
    t.lt(130)
    t.fd(a)
    t.lt(140)



import turtle

t = turtle.Turtle()

turtle.pensize(5)
turtle.bgcolor("light blue")
t.penup()
t.goto(-100,-100)
t.pendown()

#Vẽ nhà
t.fillcolor("beige")
t.begin_fill()
rectangular1(100)
t.end_fill()
t.goto(0,-100)
t.fillcolor("Red")
t.begin_fill()
rectangular2(45)
t.end_fill()

t.penup()
t.goto(-100,-0)
t.pendown()
t.fillcolor("orange")
t.begin_fill()
t.lt(30)
t.fd(150)
t.rt(80)
t.fd(100)
t.end_fill()
t.rt(180)
t.fd(60)
t.rt(40)
t.fillcolor("gray")
t.begin_fill()
t.fd(20)
t.rt(90)
t.fd(20)
t.rt(90)
t.fd(45)
t.end_fill()

t.penup()
t.goto(62,75)
t.pendown()
t.rt(180)
t.fd(15)
t.penup()
t.goto(72,75)
t.pendown()
t.fd(25)

# Ve cay


        
turtle.pensize(5)
t.penup()
t.goto(210,-150)
t.pendown()
t.rt(90)

t.fillcolor("brown")
t.begin_fill()
rectangular3(40)
t.end_fill()

t.penup()
t.goto(150,-50)
t.pendown()
t.fillcolor("dark green")
t.begin_fill()
t.fd(160)
triangle(115)
t.end_fill()

t.penup()
t.goto(155,30)
t.pendown()
t.lt(135)
t.fillcolor("green")
t.begin_fill()
t.fd(140)
triangle(100)
t.end_fill()

t.penup()
t.goto(165,100)
t.pendown()
t.lt(135)
t.fillcolor("lightgreen")
t.begin_fill()
t.fd(120)
triangle(85)
t.end_fill()

t.penup()
t.goto(-150,-150)
t.pendown()
t.rt(135)

t.fillcolor("brown")
t.begin_fill()
rectangular1(25)
t.end_fill()


t.penup()
t.goto(-215,-100)
t.pendown()
t.fillcolor("dark green")
t.begin_fill()
t.rt(90)
triangle2(80)
t.goto(-215,-100)
t.end_fill()

t.penup()
t.goto(-205,-45)
t.pendown()
t.fillcolor("green")
t.begin_fill()
t.lt(90)
triangle2(60)
t.goto(-205,-45)
t.end_fill()

t.penup()
t.goto(-195,0)
t.pendown()
t.fillcolor("light green")
t.begin_fill()
t.lt(90)
triangle2(40)
t.goto(-195,0)
t.end_fill()

# Vẽ ông mặt trời
t.penup()
t.goto(100,150)
t.pendown()
t.lt(135)
t.fillcolor("yellow")
t.begin_fill()
t.circle(50)
t.end_fill()
t.rt(90)
t.fd(50)
t.rt(180)
t.fd(50)

t.penup()
t.fd(100)
t.pendown()
t.fd(50)
t.rt(180)
t.fd(50)

t.rt(86)
t.penup()
for i in range(40):
    t.fd(1)
    t.lt(1)
t.pendown()
t.rt(90)
t.fd(30)
t.rt(180)
t.fd(30)
t.penup()
t.fd(100)
t.pendown()
t.fd(30)
t.rt(180)
t.fd(30)

t.rt(86)
t.penup()
for i in range(40):
    t.fd(1)
    t.lt(1)
t.pendown()
t.rt(90)
t.fd(50)
t.rt(180)
t.fd(50)
t.penup()
t.fd(100)
t.pendown()
t.fd(50)
t.rt(180)
t.fd(50)

t.rt(86)
t.penup()
for i in range(40):
    t.fd(1)
    t.lt(1)
t.pendown()
t.rt(90)
t.fd(30)
t.rt(180)
t.fd(30)
t.penup()
t.fd(100)
t.pendown()
t.fd(30)
t.rt(180)
t.fd(30)

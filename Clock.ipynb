# %%
import turtle
import math
import datetime as dt


t = turtle.Turtle()

class Clock():
    def __init__(self,x,y,r):
        
        self.x = x
        self.y = y
        self.r = r
    
    def vedongho(self):
        t.penup()
        t.goto(self.x,self.y - self.r)
        t.pendown()
        t.pensize(3)
        t.circle(self.r)
        
        
        for i in range(12):
            t.penup()
            t.goto(self.x,self.y)
            t.pendown()
            t.penup()
            t.fd(self.r - 25)
            t.pendown()
            t.pensize(2)
            t.fd(15)
            t.bk(15)
            t.penup()
            t.bk(self.r - 25)
            t.pendown()
            t.lt(6)
            for i in range(4):
                t.penup()
                t.fd(self.r - 20)
                t.pendown()
                t.pensize(1)
                t.fd(10)
                t.bk(10)
                t.penup()
                t.bk(self.r - 20)
                t.pendown()
                t.lt(6)

    def vekimdongho(self):
        t.lt(90)
        t.pencolor("red")
        t.pensize(1)
        t.fd(self.r-22)
        t.bk(self.r-22)
        
        t.lt(30)
        t.pencolor("black")
        t.pensize(2)
        
        t.fd(self.r/2+20)
        t.bk(self.r/2+20)
        
        t.lt(30)
        t.pensize(3)
        t.fd(self.r/2)
        t.bk(self.r/2)
        
    def time(self):
        sec = dt.datetime.now().second
        min = dt.datetime.now().minute
        hr = dt.datetime.now().hour
        
        while True:
            t.hideturtle()
            t.clear()
            # display the time
            t.write(str(hr).zfill(2)+":"+str(min).zfill(2)+":"+str(sec).zfill(2),
            font =("Arial Narrow", 35, "bold"))
            time.sleep(1)
            sec+= 1
     
        if sec == 60:
            sec = 0
            min+= 1
     
        if min == 60:
            min = 0
            hr+= 1
     
        if hr == 13:
            hr = 1
a = Clock(0,0,100)
a.vedongho()
a.vekimdongho()
a.time()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [3], line 95
#      93 a.vedongho()
#      94 a.vekimdongho()
# ---> 95 a.time()
#
# Cell In [3], line 79, in Clock.time(self)
#      76     # display the time
#      77     t.write(str(hr).zfill(2)+":"+str(min).zfill(2)+":"+str(sec).zfill(2),
#      78     font =("Arial Narrow", 35, "bold"))
# ---> 79     time.sleep(1)
#      80     sec+= 1
#      82 if sec == 60:
#
# AttributeError: type object 'datetime.time' has no attribute 'sleep'

# %%
import turtle

t = turtle.Turtle()

turtle.pensize(5)
turtle.bgcolor("light blue")
t.penup()
t.goto(-250,-250)
t.pendown()

#Vẽ nhà
t.fillcolor("blue")
t.begin_fill()
for i in range(4):
    t.fd(200)
    t.lt(90)
t.end_fill()

t.goto(-175,-250)
t.fillcolor("light green")
t.begin_fill()
for i in range(2):
    t.fd(50)
    t.lt(90)
    t.fd(100)
    t.lt(90)
t.end_fill()

t.penup()
t.goto(-250,-50)
t.pendown()
t.fillcolor("pink")
t.begin_fill()
t.fd(200)
t.lt(135)
t.fd(142)
t.lt(90)
t.fd(142)
t.end_fill()

t.penup()
t.goto(-50,-50)
t.pendown()
t.rt(90)
t.fillcolor("orange")
t.begin_fill()
for i in range(2):
    t.fd(142)
    t.rt(105)
    t.fd(145)
    t.rt(75)
t.end_fill()

t.rt(105)
t.fillcolor("yellow")
t.begin_fill()
t.fd(145)
t.rt(120)
t.fd(200)
t.rt(60)
t.fd(145)
t.end_fill()

t.penup()
t.goto(0,-75)
t.pendown()
t.lt(60)
t.fillcolor("red")
t.begin_fill()
t.fd(50)
t.lt(120)
t.fd(50)
t.lt(60)
t.fd(50)
t.end_fill()

# Vẽ cây
turtle.pensize(5)
turtle.bgcolor("light blue")
t.penup()
t.goto(200,-250)
t.pendown()
t.rt(90)

t.fillcolor("brown")
t.begin_fill()
for i in range(2):
    t.fd(40)
    t.lt(90)
    t.fd(100)
    t.lt(90)
t.end_fill()

t.penup()
t.goto(140,-150)
t.pendown()
t.fillcolor("green")
t.begin_fill()
t.fd(160)
t.lt(135)
t.fd(114)
t.lt(90)
t.fd(114)
t.end_fill()


t.penup()
t.goto(150,-68)
t.pendown()
t.lt(135)
t.fillcolor("green")
t.begin_fill()
t.fd(140)
t.lt(135)
t.fd(100)
t.lt(90)
t.fd(100)
t.end_fill()

t.penup()
t.goto(160,5)
t.pendown()
t.lt(135)
t.fillcolor("green")
t.begin_fill()
t.fd(120)
t.lt(135)
t.fd(85)
t.lt(90)
t.fd(85)
t.end_fill()

# Vẽ ông mặt trời
t.penup()
t.goto(100,150)
t.pendown()
t.lt(135)
t.fillcolor("yellow")
t.begin_fill()
t.circle(50)
t.end_fill()
t.rt(90)
t.fd(50)
t.rt(180)
t.fd(50)

t.penup()
t.fd(100)
t.pendown()
t.fd(50)
t.rt(180)
t.fd(50)

t.rt(86)
t.penup()
for i in range(40):
    t.fd(1)
    t.lt(1)
t.pendown()
t.rt(90)
t.fd(30)
t.rt(180)
t.fd(30)
t.penup()
t.fd(100)
t.pendown()
t.fd(30)
t.rt(180)
t.fd(30)

t.rt(86)
t.penup()
for i in range(40):
    t.fd(1)
    t.lt(1)
t.pendown()
t.rt(90)
t.fd(50)
t.rt(180)
t.fd(50)
t.penup()
t.fd(100)
t.pendown()
t.fd(50)
t.rt(180)
t.fd(50)

t.rt(86)
t.penup()
for i in range(40):
    t.fd(1)
    t.lt(1)
t.pendown()
t.rt(90)
t.fd(30)
t.rt(180)
t.fd(30)
t.penup()
t.fd(100)
t.pendown()
t.fd(30)
t.rt(180)
t.fd(30)
